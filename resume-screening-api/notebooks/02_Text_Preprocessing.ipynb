# %% [markdown]
# # Resume Screening System - NLP Text Preprocessing
#
# This notebook performs preprocessing and normalization of resume text using NLP techniques before machine learning model training.

# %%
# !pip install nltk
# Out:
# ...
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.6 MB 217.9 kB/s eta 0:00:07
#      - -------------------------------------- 0.1/1.6 MB 297.7 kB/s eta 0:00:06
#      --- ------------------------------------ 0.1/1.6 MB 607.9 kB/s eta 0:00:03
#      ------ --------------------------------- 0.3/1.6 MB 923.9 kB/s eta 0:00:02
#      ---------- ----------------------------- 0.4/1.6 MB 1.2 MB/s eta 0:00:01
#      ------------- -------------------------- 0.5/1.6 MB 1.4 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.7/1.6 MB 1.6 MB/s eta 0:00:01
#      ---------------------- ----------------- 0.9/1.6 MB 1.9 MB/s eta 0:00:01
#      -------------------------- ------------- 1.0/1.6 MB 2.1 MB/s eta 0:00:01
# ...

# %%
import nltk

print("NLTK installed successfully")
# Out:
# NLTK installed successfully

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Akshitha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
def clean_text(text):

    text = text.lower()

    text = re.sub(r'[^a-zA-Z]', ' ', text)

    text = re.sub(r'\s+', ' ', text)

    return text

# %%
import pandas as pd

df = pd.read_csv("../data/resume_dataset.csv")

df.head()
# Out:
#                                               resume            category
# 0  Python developer with machine learning experience      Data Scientist
# 1            Java backend developer with spring boot   Backend Developer
# 2        Frontend developer with html css javascript  Frontend Developer
# 3           Android developer with kotlin experience    Mobile Developer
# 4             Data analyst with sql and excel skills        Data Analyst

# %%
def clean_text(text):

    text = text.lower()

    text = re.sub(r'[^a-zA-Z]', ' ', text)

    text = re.sub(r'\s+', ' ', text)

    return text

# %%
df['clean_resume'] = df['resume'].apply(clean_text)

df.head()
# Out:
#                                               resume            category  \
# 0  Python developer with machine learning experience      Data Scientist
# 1            Java backend developer with spring boot   Backend Developer
# 2        Frontend developer with html css javascript  Frontend Developer
# 3           Android developer with kotlin experience    Mobile Developer
# 4             Data analyst with sql and excel skills        Data Analyst
#
#                                         clean_resume
# 0  python developer with machine learning experience
# 1            java backend developer with spring boot
# 2        frontend developer with html css javascript
# 3           android developer with kotlin experience
# 4             data analyst with sql and excel skills

# %% [markdown]
# # Stopword Removal
#
# Common English stopwords are removed to improve text quality for machine learning models.

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(text):

    words = text.split()

    filtered_words = [
        word for word in words
        if word not in stop_words
    ]

    return " ".join(filtered_words)

# %%
df['clean_resume'] = df['clean_resume'].apply(
    remove_stopwords
)

df.head()
# Out:
#                                               resume            category  \
# 0  Python developer with machine learning experience      Data Scientist
# 1            Java backend developer with spring boot   Backend Developer
# 2        Frontend developer with html css javascript  Frontend Developer
# 3           Android developer with kotlin experience    Mobile Developer
# 4             Data analyst with sql and excel skills        Data Analyst
#
#                                    clean_resume
# 0  python developer machine learning experience
# 1            java backend developer spring boot
# 2        frontend developer html css javascript
# 3           android developer kotlin experience
# 4                 data analyst sql excel skills

# %% [markdown]
# # Before vs After NLP Cleaning

# %%
print("ORIGINAL RESUME:\n")

print(df['resume'].iloc[0])

print("\nCLEANED RESUME:\n")

print(df['clean_resume'].iloc[0])
# Out:
# ORIGINAL RESUME:
#
# Python developer with machine learning experience
#
# CLEANED RESUME:
#
# python developer machine learning experience
