# %% [markdown]
# # Resume Screening System - Exploratory Data Analysis (EDA)
#
# This notebook explores the dataset used for building an AI-based Resume Screening System.
# We analyze class distribution, missing values, and text patterns.

# %%
# !pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/294.9 kB ? eta -:--:--
#      ----- ------------------------------- 41.0/294.9 kB 388.9 kB/s eta 0:00:01
#      ------------------------------- ------ 245.8/294.9 kB 1.7 MB/s eta 0:00:01
#      ------------------------------------ - 286.7/294.9 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 294.9/294.9 kB 1.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
print("Seaborn installed successfully")
# Out:
# Seaborn installed successfully

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
import pandas as pd

df = pd.read_csv("../data/resume_dataset.csv")
df.head()
# Out:
#                                               resume            category
# 0  Python developer with machine learning experience      Data Scientist
# 1            Java backend developer with spring boot   Backend Developer
# 2        Frontend developer with html css javascript  Frontend Developer
# 3           Android developer with kotlin experience    Mobile Developer
# 4             Data analyst with sql and excel skills        Data Analyst

# %%
# !pip install wordcloud
# Out:
# ...
#      ---------------------------------------- 0.0/306.2 kB ? eta -:--:--
#      --------------------- ---------------- 174.1/306.2 kB 3.5 MB/s eta 0:00:01
#      -------------------------------------- 306.2/306.2 kB 4.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
plt.figure(figsize=(7,4))

sns.countplot(
    data=df,
    y='category',
    order=df['category'].value_counts().index
)

plt.title("Resume Category Distribution")
plt.xlabel("Count")
plt.ylabel("Category")

plt.show()

# %%
plt.figure(figsize=(5,5))

df['category'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=140
)

plt.title("Resume Category Percentage Distribution")

plt.ylabel("")

plt.show()

# %%
plt.figure(figsize=(7,4))

sns.histplot(df['text_length'], bins=10, kde=True)

plt.title("Distribution of Resume Text Length")
plt.xlabel("Text Length")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(7,2))

sns.boxplot(x=df['word_count'])

plt.title("Resume Word Count Distribution")
plt.xlabel("Word Count")

plt.show()

# %%
plt.figure(figsize=(8,4))

plt.imshow(wordcloud, interpolation='bilinear')

plt.axis('off')

plt.title("Most Frequent Words in Resumes")

plt.show()

# %% [markdown]
# # Exploratory Data Analysis Pipeline Report
#
# | S.No | Analysis Stage | Technique / Method | Tools & Libraries | Objective | Result Generated |
# |---|---|---|---|---|---|
# | 1 | Dataset Import | CSV Data Loading | Pandas | Load structured resume dataset into notebook environment | Resume dataset successfully loaded |
# | 2 | Dataset Inspection | Dataframe Exploration | Pandas | Analyze dataset structure, records, and columns | Dataset overview generated |
# | 3 | Resume Category Analysis | Frequency Distribution | Pandas, Seaborn | Understand distribution of resume categories | Category insights extracted |
# | 4 | Category Visualization | Horizontal Count Plot | Seaborn, Matplotlib | Visualize occurrence of job domains | Professional bar graph generated |
# | 5 | Percentage Distribution | Pie Chart Visualization | Matplotlib | Analyze proportional category representation | Percentage distribution visualized |
# | 6 | Text Length Analysis | Character Count Computation | Pandas | Measure variation in resume text size | Text length metrics generated |
# | 7 | Word Count Analysis | Token Distribution Analysis | Pandas, Seaborn | Evaluate content density across resumes | Statistical distribution visualized |
# | 8 | NLP Keyword Extraction | Word Frequency Visualization | WordCloud, Matplotlib | Identify dominant technical keywords and skills | Word cloud generated successfully |
# | 9 | EDA Workflow Completion | Exploratory Data Analysis Pipeline | Python Ecosystem | Prepare dataset for NLP preprocessing and ML training | Dataset validated and analysis completed |
#
# | Current Project Status | Progress |
# |---|---|
# | Exploratory Data Analysis | Completed |
# | NLP Preprocessing | In Progress |
# | Machine Learning Training | Pending |
# | Flask API Integration | Pending |
# | Docker Deployment | Pending |
